# %% [markdown]
# ## DAG individual neighbourhoods.csv

# %% [markdown]
# ### 0. Importamos librerías

# %%
import json
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %% [markdown]
# ### 1. Carga de datos

# %%
# Rutas de los ficheros 
PATH_CSV     = "../data/neighbourhoods.csv"
PATH_GEOJSON = "../data/neighbourhoods.geojson"
PATH_LISTINGS = "../data/listings.csv"

# Carga del CSV de barrios
df_neighbourhoods = pd.read_csv(PATH_CSV)
print(f"neighbourhoods.csv: {df_neighbourhoods.shape[0]} filas, {df_neighbourhoods.shape[1]} columnas")
print(df_neighbourhoods)
print()

# Carga del GeoJSON 
gdf = gpd.read_file(PATH_GEOJSON)
print(f"neighbourhoods.geojson: {len(gdf)} features")
print(gdf[["neighbourhood", "neighbourhood_group", "geometry"]].head(12))
print()

# Carga de listings (para cruzar barrios) 
columnas_dag = ["id", "neighbourhood_cleansed", "price", "availability_365", "number_of_reviews", "room_type"]
df_listings = pd.read_csv(PATH_LISTINGS, usecols=columnas_dag)

print(f"listings.csv: {df_listings.shape[0]} filas cargadas.")
print(df_listings["neighbourhood_cleansed"].value_counts())
print()
# Out:
# neighbourhoods.csv: 11 filas, 2 columnas
#     neighbourhood_group         neighbourhood
# 0                   NaN     Bailen-Miraflores
# 1                   NaN           Campanillas
# 2                   NaN    Carretera de Cadiz
# 3                   NaN                Centro
# 4                   NaN             Churriana
# 5                   NaN         Ciudad Jardin
# 6                   NaN   Cruz De Humilladero
# 7                   NaN                  Este
# 8                   NaN        Palma-Palmilla
# 9                   NaN    Puerto de la Torre
# 10                  NaN  Teatinos-Universidad
#
# neighbourhoods.geojson: 11 features
#            neighbourhood neighbourhood_group  \
# 0              Churriana                None
# 1     Carretera de Cadiz                None
# 2   Teatinos-Universidad                None
# 3         Palma-Palmilla                None
# 4          Ciudad Jardin                None
# 5                   Este                None
# 6                 Centro                None
# 7            Campanillas                None
# 8     Puerto de la Torre                None
# 9    Cruz De Humilladero                None
# 10     Bailen-Miraflores                None
#
#                                              geometry
# 0   MULTIPOLYGON Z (((-4.51628 36.69605 9.31323e-1...
# 1   MULTIPOLYGON Z (((-4.43052 36.71173 1.86264e-9...
# 2   MULTIPOLYGON Z (((-4.50119 36.71986 9.31323e-1...
# 3   MULTIPOLYGON Z (((-4.4661 36.84946 9.31323e-10...
# 4   MULTIPOLYGON Z (((-4.37232 36.89221 9.31323e-1...
# 5   MULTIPOLYGON Z (((-4.28342 36.77315 0, -4.2835...
# 6   MULTIPOLYGON Z (((-4.41453 36.69872 1.86264e-9...
# 7   MULTIPOLYGON Z (((-4.50284 36.79429 -9.31323e-...
# 8   MULTIPOLYGON Z (((-4.46756 36.81662 9.31323e-1...
# 9   MULTIPOLYGON Z (((-4.45845 36.72532 0, -4.4583...
# 10  MULTIPOLYGON Z (((-4.44648 36.74137 9.31323e-1...
#
# listings.csv: 9714 filas cargadas.
# neighbourhood_cleansed
# Centro                  6389
# Este                     989
# Carretera de Cadiz       935
# Cruz De Humilladero      460
# Bailen-Miraflores        312
# Palma-Palmilla           217
# Churriana                150
# Teatinos-Universidad     100
# Ciudad Jardin             88
# Puerto de la Torre        41
# Campanillas               33
# Name: count, dtype: int64

# %% [markdown]
# ### 2. Exploración inicial

# %%
# Tipos de datos y nulos en neighbourhoods.csv 
print("- Tipos de datos")
print(df_neighbourhoods.dtypes)
print()
print("- Valores nulos por columna")
print(df_neighbourhoods.isnull().sum())
print()
print("- Valores únicos por columna")
for col in df_neighbourhoods.columns:
    print(f"  {col}: {df_neighbourhoods[col].nunique()} únicos → {df_neighbourhoods[col].unique()}")
# Out:
# - Tipos de datos
# neighbourhood_group    float64
# neighbourhood              str
# dtype: object
#
# - Valores nulos por columna
# neighbourhood_group    11
# neighbourhood           0
# dtype: int64
#
# - Valores únicos por columna
#   neighbourhood_group: 0 únicos → [nan]
#   neighbourhood: 11 únicos → <StringArray>
# [   'Bailen-Miraflores',          'Campanillas',   'Carretera de Cadiz',
#                'Centro',            'Churriana',        'Ciudad Jardin',
#   'Cruz De Humilladero',                 'Este',       'Palma-Palmilla',
#    'Puerto de la Torre', 'Teatinos-Universidad']
# Length: 11, dtype: str

# %%
# Exploración del GeoJSON 
print("- Nulos en GeoJSON")
print(gdf[["neighbourhood", "neighbourhood_group"]].isnull().sum())
# Out:
# - Nulos en GeoJSON
# neighbourhood           0
# neighbourhood_group    11
# dtype: int64

# %% [markdown]
# ### 3- Limpieza y validación

# %%
# 3.1 Eliminar columna neighbourhood_group (vacía al 100%) 
print("Antes:", df_neighbourhoods.columns.tolist())
df_neighbourhoods = df_neighbourhoods.drop(columns=["neighbourhood_group"])
gdf = gdf.drop(columns=["neighbourhood_group"])
print("Después:", df_neighbourhoods.columns.tolist())
# Out:
# Antes: ['neighbourhood_group', 'neighbourhood']
# Después: ['neighbourhood']

# %%
# 3.2 Verificar que los barrios del CSV y el GeoJSON coinciden 
barrios_csv = set(df_neighbourhoods["neighbourhood"])
barrios_geo = set(gdf["neighbourhood"])

solo_en_csv = barrios_csv - barrios_geo
solo_en_geo = barrios_geo - barrios_csv

if not solo_en_csv and not solo_en_geo:
    print("[CORRECTO] CSV y GeoJSON tienen exactamente los mismos 11 barrios.")
else:
    print(f"[AVISO] Solo en CSV: {solo_en_csv}")
    print(f"[AVISO] Solo en GeoJSON: {solo_en_geo}")
# Out:
# [CORRECTO] CSV y GeoJSON tienen exactamente los mismos 11 barrios.

# %%
# 3.3 Verificar que los barrios de listings coinciden con los conocidos 
barrios_listings = set(df_listings["neighbourhood_cleansed"].dropna().unique())
barrios_conocidos = barrios_csv

desconocidos = barrios_listings - barrios_conocidos
print(f"Barrios en listings no presentes en neighbourhoods.csv: {desconocidos}")

# Listings sin barrio asignado (NaN)
nulos_barrio = df_listings["neighbourhood_cleansed"].isnull().sum()
print(f"Listings sin barrio (NaN): {nulos_barrio}")
# Out:
# Barrios en listings no presentes en neighbourhoods.csv: set()
# Listings sin barrio (NaN): 0

# %% [markdown]
# ### 4. Transformación de Datos

# %%
# 4.1 Definir agrupación geográfica de barrios 
# Basada en proximidad geográfica dentro de Málaga
GRUPOS_BARRIOS = {
    "Centro"   : ["Centro"],
    "Este"     : ["Este"],
    "Oeste"    : ["Carretera de Cadiz", "Cruz De Humilladero", "Teatinos-Universidad", "Churriana", "Campanillas", "Puerto de la Torre"],
    "Norte"    : ["Bailen-Miraflores", "Palma-Palmilla", "Ciudad Jardin"],
}

# Construir mapa inverso: {barrio: grupo}
mapa_barrio_grupo = {
    barrio: grupo
    for grupo, barrios in GRUPOS_BARRIOS.items()
    for barrio in barrios
}

print("Mapa barrio -> grupo:")
for k, v in mapa_barrio_grupo.items():
    print(f"  {k:30s} -> {v}")
# Out:
# Mapa barrio -> grupo:
#   Centro                         -> Centro
#   Este                           -> Este
#   Carretera de Cadiz             -> Oeste
#   Cruz De Humilladero            -> Oeste
#   Teatinos-Universidad           -> Oeste
#   Churriana                      -> Oeste
#   Campanillas                    -> Oeste
#   Puerto de la Torre             -> Oeste
#   Bailen-Miraflores              -> Norte
#   Palma-Palmilla                 -> Norte
#   Ciudad Jardin                  -> Norte

# %%
# 4.2 Asignar neighbourhood_group al CSV y al GeoJSON 
df_neighbourhoods["neighbourhood_group"] = (
    df_neighbourhoods["neighbourhood"].map(mapa_barrio_grupo)
)

gdf["neighbourhood_group"] = (
    gdf["neighbourhood"].map(mapa_barrio_grupo)
)

print(df_neighbourhoods)
# Out:
#            neighbourhood neighbourhood_group
# 0      Bailen-Miraflores               Norte
# 1            Campanillas               Oeste
# 2     Carretera de Cadiz               Oeste
# 3                 Centro              Centro
# 4              Churriana               Oeste
# 5          Ciudad Jardin               Norte
# 6    Cruz De Humilladero               Oeste
# 7                   Este                Este
# 8         Palma-Palmilla               Norte
# 9     Puerto de la Torre               Oeste
# 10  Teatinos-Universidad               Oeste

# %% [markdown]
# ### 5. Enriquecimiento de Datos

# %%
# 1. Lista de columnas que estamos añadiendo (para poder limpiar)
cols_enriquecimiento = ['num_anuncios', 'precio_medio', 'disponibilidad_media', 'reviews_totales']

# 2. LIMPIEZA PREVENTIVA: 
# Borramos las columnas si ya existen para evitar el error de duplicados al re-ejecutar
for col in cols_enriquecimiento:
    if col in df_neighbourhoods.columns:
        df_neighbourhoods = df_neighbourhoods.drop(columns=[col])
    if col in gdf.columns:
        gdf = gdf.drop(columns=[col])

# 3. Calculamos las estadísticas de listings
stats_barrios = df_listings.groupby('neighbourhood_cleansed').agg(
    num_anuncios=('id', 'count'),
    precio_medio=('price', 'mean'),
    disponibilidad_media=('availability_365', 'mean'),
    reviews_totales=('number_of_reviews', 'sum')
).reset_index()

# 4. Realizamos la unión (MERGE)
df_neighbourhoods = df_neighbourhoods.merge(stats_barrios, on='neighbourhood', how='left')
gdf = gdf.merge(stats_barrios, on='neighbourhood', how='left')

# 5. Rellenamos con 0 
for col in cols_enriquecimiento:
    df_neighbourhoods[col] = df_neighbourhoods[col].fillna(0)
    gdf[col] = gdf[col].fillna(0)

print("Enriquecimiento aplicado correctamente, junto con la limpieza previa afirmada.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 13
#      10         gdf = gdf.drop(columns=[col])
#      12 # 3. Calculamos las estadísticas de listings
# ---> 13 stats_barrios = df_listings.groupby('neighbourhood_cleansed').agg(
#      14     num_anuncios=('id', 'count'),
#      15     precio_medio=('price', 'mean'),
#      16     disponibilidad_media=('availability_365', 'mean'),
#      17     reviews_totales=('number_of_reviews', 'sum')
#      18 ).reset_index()
#      20 # 4. Realizamos la unión (MERGE)
#      21 df_neighbourhoods = df_neighbourhoods.merge(stats_barrios, on='neighbourhood', how='left')
#
# File ~/Universidad/3o/2o-cuatri/SDPDII/Practicas/proy_SSDD_II/.venv/lib/python3.12/site-packages/pandas/core/groupby/generic.py:2291, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    2288     kwargs["engine_kwargs"] = engine_kwargs
#    2290 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 2291 result = op.agg()
#    2292 if not is_dict_like(func) and result is not None:
#    2293     # GH #52849
#    2294     if not self.as_index and is_list_like(func):
#
# File ~/Universidad/3o/2o-cuatri/SDPDII/Practicas/proy_SSDD_II/.venv/lib/python3.12/site-packages/pandas/core/apply.py:294, in Apply.agg(self)
#     291     return self.apply_str()
#     293 if is_dict_like(func):
# --> 294     return self.agg_dict_like()
#     295 elif is_list_like(func):
#     296     # we require a list, but not a 'str'
#     297     return self.agg_list_like()
#
# File ~/Universidad/3o/2o-cuatri/SDPDII/Practicas/proy_SSDD_II/.venv/lib/python3.12/site-packages/pandas/core/apply.py:511, in Apply.agg_dict_like(self)
#     503 def agg_dict_like(self) -> DataFrame | Series:
#     504     """
#     505     Compute aggregation in the case of a dict-like argument.
#     506
#    (...)    509     Result of aggregation.
#     510     """
# --> 511     return self.agg_or_apply_dict_like(op_name="agg")
#
# File ~/Universidad/3o/2o-cuatri/SDPDII/Practicas/proy_SSDD_II/.venv/lib/python3.12/site-packages/pandas/core/apply.py:1677, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1672     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1674 with com.temp_setattr(
#    1675     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1676 ):
# -> 1677     result_index, result_data = self.compute_dict_like(
#    1678         op_name, selected_obj, selection, kwargs
#    1679     )
#    1680 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1681 return result
#
# File ~/Universidad/3o/2o-cuatri/SDPDII/Practicas/proy_SSDD_II/.venv/lib/python3.12/site-packages/pandas/core/apply.py:592, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     590 if cols.ndim == 1:
#     591     series = obj._gotitem(key, ndim=1, subset=cols)
# --> 592     results.append(getattr(series, op_name)(how, **kwargs))
#     593     keys.append(key)
#     594 else:
#
# File ~/Universidad/3o/2o-cuatri/SDPDII/Practicas/proy_SSDD_II/.venv/lib/python3.12/site-packages/pandas/core/groupby/generic.py:464, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     462 kwargs["engine"] = engine
#     463 kwargs["engine_kwargs"] = engine_kwargs
# --> 464 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     465 if relabeling:
#     466     # columns is not narrowed by mypy from relabeling flag
#     467     assert columns is not None  # for mypy
#
# File ~/Universidad/3o/2o-cuatri/SDPDII/Practicas/proy_SSDD_II/.venv/lib/python3.12/site-packages/pandas/core/groupby/generic.py:522, in SeriesGroupBy._aggregate_multiple_funcs(self, arg, *args, **kwargs)
#     520     for idx, (name, func) in enumerate(arg):
#     521         key = base.OutputKey(label=name, position=idx)
# --> 522         results[key] = self.aggregate(func, *args, **kwargs)
#     524 if any(isinstance(x, DataFrame) for x in results.values()):
#     525     from pandas import concat
#
# File ~/Universidad/3o/2o-cuatri/SDPDII/Practicas/proy_SSDD_II/.venv/lib/python3.12/site-packages/pandas/core/groupby/generic.py:456, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     454     if engine_kwargs is not None:
#     455         kwargs["engine_kwargs"] = engine_kwargs
# --> 456     return getattr(self, func)(*args, **kwargs)
#     458 elif isinstance(func, abc.Iterable):
#     459     # Catch instances of lists / tuples
#     460     # but not the class list / tuple itself.
#     461     func = maybe_mangle_lambdas(func)
#
# File ~/Universidad/3o/2o-cuatri/SDPDII/Practicas/proy_SSDD_II/.venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File ~/Universidad/3o/2o-cuatri/SDPDII/Practicas/proy_SSDD_II/.venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File ~/Universidad/3o/2o-cuatri/SDPDII/Practicas/proy_SSDD_II/.venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:2274, in SingleBlockManager.grouped_reduce(self, func)
#    2272 def grouped_reduce(self, func):
#    2273     arr = self.array
# -> 2274     res = func(arr)
#    2275     index = default_index(len(res))
#    2277     mgr = type(self).from_array(res, index)
#
# File ~/Universidad/3o/2o-cuatri/SDPDII/Practicas/proy_SSDD_II/.venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1783, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1781 def array_func(values: ArrayLike) -> ArrayLike:
#    1782     try:
# -> 1783         result = self._grouper._cython_operation(
#    1784             "aggregate",
#    1785             values,
#    1786             how,
#    1787             axis=data.ndim - 1,
#    1788             min_count=min_count,
#    1789             **kwargs,
#    1790         )
#    1791     except NotImplementedError:
#    1792         # generally if we have numeric_only=False
#    1793         # and non-applicable functions
#    1794         # try to python agg
#    1795         # TODO: shouldn't min_count matter?
#    1796         # TODO: avoid special casing SparseArray here
#    1797         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File ~/Universidad/3o/2o-cuatri/SDPDII/Practicas/proy_SSDD_II/.venv/lib/python3.12/site-packages/pandas/core/groupby/ops.py:963, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     959 assert kind in ["transform", "aggregate"]
#     961 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
# --> 963 return cy_op.cython_operation(
#     964     values=values,
#     965     axis=axis,
#     966     min_count=min_count,
#     967     comp_ids=self.ids,
#     968     ngroups=self.ngroups,
#     969     **kwargs,
#     970 )
#
# File ~/Universidad/3o/2o-cuatri/SDPDII/Practicas/proy_SSDD_II/.venv/lib/python3.12/site-packages/pandas/core/groupby/ops.py:553, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     549 self._validate_axis(axis, values)
#     551 if not isinstance(values, np.ndarray):
#     552     # i.e. ExtensionArray
# --> 553     return values._groupby_op(
#     554         how=self.how,
#     555         has_dropped_na=self.has_dropped_na,
#     556         min_count=min_count,
#     557         ngroups=ngroups,
#     558         ids=comp_ids,
#     559         **kwargs,
#     560     )
#     562 return self._cython_op_ndim_compat(
#     563     values,
#     564     min_count=min_count,
#    (...)    568     **kwargs,
#     569 )
#
# File ~/Universidad/3o/2o-cuatri/SDPDII/Practicas/proy_SSDD_II/.venv/lib/python3.12/site-packages/pandas/core/arrays/base.py:2807, in ExtensionArray._groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2793 if isinstance(self.dtype, StringDtype):
#    2794     # StringArray
#    2795     if op.how in [
#    2796         "prod",
#    2797         "mean",
#    (...)   2805         "kurt",
#    2806     ]:
# -> 2807         raise TypeError(
#    2808             f"dtype '{self.dtype}' does not support operation '{how}'"
#    2809         )
#    2810     if op.how not in ["any", "all"]:
#    2811         # Fail early to avoid conversion to object
#    2812         op._get_cython_function(op.kind, op.how, np.dtype(object), False)
#
# TypeError: dtype 'str' does not support operation 'mean'

# %% [markdown]
# ### 6. Visualización de Datos

# %%
# 5.1 Mapa de barrios coloreado por grupo geográfico 
COLORES_GRUPOS = {
    "Centro"   : "#e63946",
    "Este"     : "#2a9d8f",
    "Oeste"    : "#e9c46a",
    "Norte"    : "#457b9d",
    "Periferia": "#a8dadc",
}

gdf["color"] = gdf["neighbourhood_group"].map(COLORES_GRUPOS)

fig, ax = plt.subplots(figsize=(10, 10))
gdf.plot(ax=ax, color=gdf["color"], edgecolor="white", linewidth=0.8)

# Etiquetas con el nombre de cada barrio
for _, row in gdf.iterrows():
    centroid = row.geometry.centroid
    ax.annotate(
        text=row["neighbourhood"],
        xy=(centroid.x, centroid.y),
        fontsize=7.5,
        ha="center",
        color="black"
    )

# Leyenda por grupo
leyenda = [
    mpatches.Patch(color=color, label=grupo)
    for grupo, color in COLORES_GRUPOS.items()
]
ax.legend(handles=leyenda, title="Grupo geográfico", loc="lower left", fontsize=9)

ax.set_title("Barrios de Málaga agrupados geográficamente", fontsize=14, fontweight="bold")
ax.set_axis_off()
plt.tight_layout()
plt.show()

# %%
# Ordenamos para mostrar los 15 barrios más caros
top_precios = df_neighbourhoods.sort_values('precio_medio', ascending=False).head(15)

plt.figure(figsize=(10, 6))
plt.barh(top_precios['neighbourhood'], top_precios['precio_medio'], color='skyblue')
plt.xlabel('Precio Medio (€)')
plt.title('Top 15 Barrios más caros de Málaga')
plt.gca().invert_yaxis()  # Para que el más caro salga arriba
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))

# Usamos la nueva variable 'disponibilidad_media'
gdf.plot(column='disponibilidad_media', 
         cmap='RdYlGn_r', # Verde (poca disponibilidad) a Rojo (mucha)
         legend=True,
         legend_kwds={'label': "Días disponibles al año (media)", 'orientation': "vertical"},
         edgecolor='black', 
         linewidth=0.5, 
         ax=ax)

ax.set_title('Disponibilidad de alojamientos por barrio en Málaga', fontsize=14)
ax.set_axis_off()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))

# Dibujamos el mapa usando la columna 'num_anuncios' para el color
gdf.plot(column='num_anuncios', 
         cmap='YlOrRd', 
         legend=True, 
         edgecolor='black', 
         linewidth=0.5, 
         ax=ax)

ax.set_title('Densidad de anuncios por barrio en Málaga', fontsize=15)
ax.set_axis_off()
plt.show()

# %%
# Ordenamos por número de anuncios para que el gráfico sea legible
df_sorted = df_neighbourhoods.sort_values('num_anuncios', ascending=False).head(15)

fig, ax1 = plt.subplots(figsize=(12, 6))

# Eje 1: Barras para la Oferta (Número de anuncios)
color_anuncios = 'skyblue'
ax1.set_xlabel('Barrios')
ax1.set_ylabel('Número de Anuncios', color='tab:blue', fontsize=12)
bars = ax1.bar(df_sorted['neighbourhood'], df_sorted['num_anuncios'], color=color_anuncios, alpha=0.7, label='Oferta (Anuncios)')
ax1.tick_params(axis='y', labelcolor='tab:blue')
plt.xticks(rotation=45, ha='right')

# Eje 2: Línea para la Actividad (Total de Reseñas)
ax2 = ax1.twinx()  # Creamos el segundo eje y
color_reviews = 'tab:red'
ax2.set_ylabel('Total de Reseñas', color=color_reviews, fontsize=12)
ax2.plot(df_sorted['neighbourhood'], df_sorted['reviews_totales'], color=color_reviews, marker='o', linewidth=2, label='Actividad (Reseñas)')
ax2.tick_params(axis='y', labelcolor=color_reviews)

# Título y ajustes
plt.title('Relación Oferta vs. Actividad por Barrio (Top 15)', fontsize=14, fontweight='bold')
fig.tight_layout()
plt.show()

# %% [markdown]
# Los barrios con más reseñas son los que más anuncios tienen como debería ser lo normal
